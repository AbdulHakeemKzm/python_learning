# %%
import os
os.listdir()
# Out:
# ['supermarkets.json',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets.csv',
#  'supermarkets.xlsx',
#  'python-csv.ipynb',
#  'supermarkets-semi-colons.txt']

# %%
import pandas

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1=pandas.read_json("supermarkets.json")
df1
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_excel("supermarkets.xlsx")
df2
# Out:
#    ID          Address           City             State Country
# 0   1     3666 21st St  San Francisco          CA 94114     USA  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3=pandas.read_csv("supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4=pandas.read_csv("supermarkets-semi-colons.txt")
df4
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df4=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";", header = None)
df5
# Out:
#     0                1              2                 3        4
# 0  ID          Address           City             State  Country  \
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#               5          6
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df5.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]
df5
# Out:
#    ID          Address           City             State  Country
# 0  ID          Address           City             State  Country  \
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            Name  Employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df5
# Out:
#    ID          Address           City             State  Country
# 0  ID          Address           City             State  Country  \
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            Name  Employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df5.set_index("ID")
# Out:
#             Address           City             State  Country          Name
# ID
# ID          Address           City             State  Country          Name  \
# 1      3666 21st St  San Francisco          CA 94114      USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5
# Out:
#    ID          Address           City             State  Country
# 0  ID          Address           City             State  Country  \
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            Name  Employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df6 = df5.set_index("ID")

# %%
df6
# Out:
#             Address           City             State  Country          Name
# ID
# ID          Address           City             State  Country          Name  \
# 1      3666 21st St  San Francisco          CA 94114      USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.set_index("ID", inplace=True)

# %%
df5
# Out:
#             Address           City             State  Country          Name
# ID
# ID          Address           City             State  Country          Name  \
# 1      3666 21st St  San Francisco          CA 94114      USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.set_index("Address", inplace=True)
df5
# Out:
#                           City             State  Country          Name
# Address
# Address                   City             State  Country          Name  \
# 3666 21st St     San Francisco          CA 94114      USA       Madeira
# 735 Dolores St   San Francisco          CA 94119      USA   Bready Shop
# 332 Hill St      San Francisco  California 94114      USA   Super River
# 3995 23rd St     San Francisco          CA 94114      USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df5.set_index("Name", inplace=True, drop=False)
df5
# Out:
#                        City             State  Country          Name
# Name
# Name                   City             State  Country          Name  \
# Madeira       San Francisco          CA 94114      USA       Madeira
# Bready Shop   San Francisco          CA 94119      USA   Bready Shop
#  Super River  San Francisco  California 94114      USA   Super River
# Ben's Shop    San Francisco          CA 94114      USA    Ben's Shop
# Sanchez       San Francisco        California      USA       Sanchez
# Richvalley    San Francisco          CA 94114      USA    Richvalley
#
#               Employees
# Name
# Name          Employees
# Madeira               8
# Bready Shop          15
#  Super River         25
# Ben's Shop           10
# Sanchez              12
# Richvalley           20

# %%
df5.loc[:,"Country"]
# Out:
# Name
# Name            Country
# Madeira             USA
# Bready Shop         USA
#  Super River        USA
# Ben's Shop          USA
# Sanchez             USA
# Richvalley          USA
# Name: Country, dtype: object

# %%
list(df5.loc[:,"Country"])
# Out:
# ['Country', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df5.iloc[1:3,1:4]
# Out:
#                 State Country         Name
# Name
# Madeira      CA 94114     USA      Madeira
# Bready Shop  CA 94119     USA  Bready Shop

# %%
df5.iloc[3,1:4]
# Out:
# State      California 94114
# Country                 USA
# Name            Super River
# Name:  Super River, dtype: object

# %%
df5.columns
# Out:
# Index(['City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df5
# Out:
#                        City             State  Country          Name
# Name
# Name                   City             State  Country          Name  \
# Madeira       San Francisco          CA 94114      USA       Madeira
# Bready Shop   San Francisco          CA 94119      USA   Bready Shop
#  Super River  San Francisco  California 94114      USA   Super River
# Ben's Shop    San Francisco          CA 94114      USA    Ben's Shop
# Sanchez       San Francisco        California      USA       Sanchez
# Richvalley    San Francisco          CA 94114      USA    Richvalley
#
#               Employees
# Name
# Name          Employees
# Madeira               8
# Bready Shop          15
#  Super River         25
# Ben's Shop           10
# Sanchez              12
# Richvalley           20

# %%
len(df5.index)
# Out:
# 7

# %%
df5["continent"]=df5.shape[0]*["North America"]

# %%
df5
# Out:
#                        City             State  Country          Name
# Name
# Name                   City             State  Country          Name  \
# Madeira       San Francisco          CA 94114      USA       Madeira
# Bready Shop   San Francisco          CA 94119      USA   Bready Shop
#  Super River  San Francisco  California 94114      USA   Super River
# Ben's Shop    San Francisco          CA 94114      USA    Ben's Shop
# Sanchez       San Francisco        California      USA       Sanchez
# Richvalley    San Francisco          CA 94114      USA    Richvalley
#
#               Employees      continent
# Name
# Name          Employees  North America
# Madeira               8  North America
# Bready Shop          15  North America
#  Super River         25  North America
# Ben's Shop           10  North America
# Sanchez              12  North America
# Richvalley           20  North America

# %%
df5.shape
# Out:
# (7, 6)

# %%
df5["continent"]=df5["Country"]+ "," + "North America"

# %%
df5
# Out:
#                        City             State  Country          Name
# Name
# Name                   City             State  Country          Name  \
# Madeira       San Francisco          CA 94114      USA       Madeira
# Bready Shop   San Francisco          CA 94119      USA   Bready Shop
#  Super River  San Francisco  California 94114      USA   Super River
# Ben's Shop    San Francisco          CA 94114      USA    Ben's Shop
# Sanchez       San Francisco        California      USA       Sanchez
# Richvalley    San Francisco          CA 94114      USA    Richvalley
#
#               Employees              continent
# Name
# Name          Employees  Country,North America
# Madeira               8      USA,North America
# Bready Shop          15      USA,North America
#  Super River         25      USA,North America
# Ben's Shop           10      USA,North America
# Sanchez              12      USA,North America
# Richvalley           20      USA,North America

# %%
df5_t=df5.T

# %%
df5_t
# Out:
# Name                        Name            Madeira        Bready Shop
# City                        City      San Francisco      San Francisco  \
# State                      State           CA 94114           CA 94119
# Country                  Country                USA                USA
# Name                        Name            Madeira        Bready Shop
# Employees              Employees                  8                 15
# continent  Country,North America  USA,North America  USA,North America
#
# Name             Super River         Ben's Shop            Sanchez
# City           San Francisco      San Francisco      San Francisco  \
# State       California 94114           CA 94114         California
# Country                  USA                USA                USA
# Name             Super River         Ben's Shop            Sanchez
# Employees                 25                 10                 12
# ...

# %%
df5_t["My Address"]=["My City",10,7,"My shop","My State","My continent"]

# %%
df5_t
# Out:
# Name                        Name            Madeira        Bready Shop
# City                        City      San Francisco      San Francisco  \
# State                      State           CA 94114           CA 94119
# Country                  Country                USA                USA
# Name                        Name            Madeira        Bready Shop
# Employees              Employees                  8                 15
# continent  Country,North America  USA,North America  USA,North America
#
# Name             Super River         Ben's Shop            Sanchez
# City           San Francisco      San Francisco      San Francisco  \
# State       California 94114           CA 94114         California
# Country                  USA                USA                USA
# Name             Super River         Ben's Shop            Sanchez
# Employees                 25                 10                 12
# ...

# %%
df5=df5_t.T

# %%
df5
# Out:
#                        City             State  Country          Name
# Name
# Name                   City             State  Country          Name  \
# Madeira       San Francisco          CA 94114      USA       Madeira
# Bready Shop   San Francisco          CA 94119      USA   Bready Shop
#  Super River  San Francisco  California 94114      USA   Super River
# Ben's Shop    San Francisco          CA 94114      USA    Ben's Shop
# Sanchez       San Francisco        California      USA       Sanchez
# Richvalley    San Francisco          CA 94114      USA    Richvalley
# My Address          My City                10        7       My shop
#
#               Employees              continent
# Name
# Name          Employees  Country,North America
# Madeira               8      USA,North America
# Bready Shop          15      USA,North America
#  Super River         25      USA,North America
# Ben's Shop           10      USA,North America
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
from geopy.geocoders import Nominatim
